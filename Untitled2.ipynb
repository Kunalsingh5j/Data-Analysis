# %% [markdown]
# <a href="https://colab.research.google.com/github/Kunalsingh5j/Data-Analysis/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
na_vals = ['NA', 'Missing']
df = pd.read_csv('survey_results_public.csv')
schema_df = pd.read_csv('survey_results_schema.csv')
df.tail(10)
# Out:
#        ResponseId                      MainBranch  \
# 83429       83430     I code primarily as a hobby
# 83430       83431  I am a developer by profession
# 83431       83432  I am a developer by profession
# 83432       83433  I am a developer by profession
# 83433       83434  I am a developer by profession
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83429                 Not employed, but looking for work
# 83430                                 Employed full-time
# 83431  Independent contractor, freelancer, or self-em...
# 83432                                 Employed full-time
# 83433  Independent contractor, freelancer, or self-em...
# 83434                                 Employed full-time
# ...

# %%
df.shape
# Out:
# (83439, 48)

# %%
pd.set_option('display.max_columns', 48)
pd.set_option('display.max_rows', 85)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df['ConvertedCompYearly']
# Out:
# 0         62268.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 83434    160500.0
# 83435      3960.0
# 83436     90000.0
# 83437    816816.0
# 83438     21168.0
# Name: ConvertedCompYearly, Length: 83439, dtype: float64

# %%
df.loc[0:2, 'Currency':'LanguageWantToWorkWith']
# Out:
#             Currency  CompTotal CompFreq  \
# 0  EUR European Euro     4800.0  Monthly
# 1                NaN        NaN      NaN
# 2                NaN        NaN      NaN
#
#                           LanguageHaveWorkedWith LanguageWantToWorkWith
# 0  C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift                  Swift
# 1                              JavaScript;Python                    NaN
# 2                       Assembly;C;Python;R;Rust      Julia;Python;Rust

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
schema_df.loc[27, 'question']
# Out:
# 'What is the primary operating system in which you work? *'

# %%
schema_df.sort_index(ascending= False, inplace=True)
schema_df
# Out:
#        qid               qname  \
# 47  QID133          SurveyEase
# 46  QID132        SurveyLength
# 45  QID131                  S6
# 44  QID125        MentalHealth
# 43  QID124       Accessibility
# 42  QID126           Ethnicity
# 41  QID136           Sexuality
# 40  QID153               Trans
# 39  QID122              Gender
# 38  QID127                 Age
# 37  QID121                  S5
# 36  QID268  NEWOtherCommsNames
# 35  QID267       NEWOtherComms
# 34  QID106              SOComm
# 33  QID102          SOPartFreq
# 32  QID101           SOAccount
# 31  QID100         SOVisitFreq
# 30  QID266          NEWSOSites
# 29   QID91                  S4
# 28  QID243            NEWStuck
# 27   QID71               OpSys
# 26  QID274      NEWCollabTools
# 25  QID275           ToolsTech
# 24  QID265            MiscTech
# 23  QID264            Webframe
# 22  QID263            Platform
# 21  QID262            Database
# 20  QID233            Language
# 19   QID61                  S3
# ...

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)
filt
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 83434    False
# 83435    False
# 83436     True
# 83437     True
# 83438    False
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: bool

# %%
df.loc[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 4               5                     I am a developer by profession
# 5               6             I am a student who is learning to code
# 9              10                     I am a developer by profession
# ...           ...                                                ...
# 83429       83430                        I code primarily as a hobby
# 83430       83431                     I am a developer by profession
# 83431       83432                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
#
#                                               Employment  \
# 1                                     Student, full-time
# ...

# %%
df.rename(columns={'ConvertedCompYearly': 'SalaryUSD'}, inplace=True)
df['SalaryUSD']
# Out:
# 0         62268.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 83434    160500.0
# 83435      3960.0
# 83436     90000.0
# 83437    816816.0
# 83438     21168.0
# Name: SalaryUSD, Length: 83439, dtype: float64

# %%
df['NEWOtherComms']
# Out:
# 0         No
# 1         No
# 2        Yes
# 3         No
# 4         No
#         ...
# 83434     No
# 83435     No
# 83436     No
# 83437     No
# 83438     No
# Name: NEWOtherComms, Length: 83439, dtype: object

# %%
df['NEWOtherComms'].map({'Yes': True, 'No': False})
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# Name: NEWOtherComms, Length: 83439, dtype: object

# %%
df['NEWOtherComms'] = df['NEWOtherComms'].map({'Yes': True, 'No': False})
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False], inplace=True)
df[['Country', 'SalaryUSD']].head(50)
# Out:
#            Country   SalaryUSD
# 65399  Afghanistan  30468516.0
# 22666  Afghanistan    155496.0
# 27198  Afghanistan     51804.0
# 31086  Afghanistan     23964.0
# 44640  Afghanistan     15132.0
# 11377  Afghanistan      9792.0
# 17486  Afghanistan      5448.0
# 51428  Afghanistan      4668.0
# 14882  Afghanistan      4200.0
# 17120  Afghanistan      3108.0
# 55150  Afghanistan       100.0
# 2069   Afghanistan         NaN
# 4544   Afghanistan         NaN
# 5100   Afghanistan         NaN
# 9564   Afghanistan         NaN
# 10945  Afghanistan         NaN
# 11131  Afghanistan         NaN
# 11461  Afghanistan         NaN
# 20301  Afghanistan         NaN
# 23456  Afghanistan         NaN
# 24552  Afghanistan         NaN
# 26034  Afghanistan         NaN
# 26955  Afghanistan         NaN
# 28378  Afghanistan         NaN
# 30552  Afghanistan         NaN
# 31504  Afghanistan         NaN
# 31596  Afghanistan         NaN
# 31890  Afghanistan         NaN
# 34427  Afghanistan         NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# 66910    45241312.0
# 65399    30468516.0
# 40586    21822250.0
# 28791    20000000.0
# 12700    19200000.0
# 9608     17500000.0
# 5305     15000000.0
# 12903    14411628.0
# 66488    12750000.0
# 7205     12500000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
#        ResponseId                                         MainBranch  \
# 1924         1925                     I am a developer by profession
# 24285       24286                     I am a developer by profession
# 46464       46465  I am not primarily a developer, but I write co...
# 15163       15164                     I am a developer by profession
# 56790       56791                     I am a developer by profession
# 22032       22033                     I am a developer by profession
# 59043       59044                     I am a developer by profession
# 22453       22454                     I am a developer by profession
# 45141       45142  I am not primarily a developer, but I write co...
# 53306       53307                     I am a developer by profession
#
#                                               Employment  \
# 1924                                  Employed full-time
# 24285  Independent contractor, freelancer, or self-em...
# ...

# %%
df['SalaryUSD'].median()
# Out:
# 56211.0

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# ResponseId       41720.0
# CompTotal        67000.0
# NEWOtherComms        0.0
# SalaryUSD        56211.0
# dtype: float64

# %%
df.describe()
# Out:
#          ResponseId     CompTotal     SalaryUSD
# count  83439.000000  4.718300e+04  4.684400e+04
# mean   41720.000000  2.119407e+69  1.184262e+05
# std    24086.908893  4.603702e+71  5.272944e+05
# min        1.000000  0.000000e+00  1.000000e+00
# 25%    20860.500000  1.600000e+04  2.702500e+04
# 50%    41720.000000  6.700000e+04  5.621100e+04
# 75%    62579.500000  1.400000e+05  1.000000e+05
# max    83439.000000  1.000000e+74  4.524131e+07

# %%
df['SalaryUSD'].count()
# Out:
# 46844

# %%
df['NEWOtherComms'].value_counts()
# Out:
# False    53364
# True     29464
# Name: NEWOtherComms, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Papua New Guinea                                            1
# Dominica                                                    1
# Saint Kitts and Nevis                                       1
# Saint Vincent and the Grenadines                            1
# Name: Country, Length: 181, dtype: int64

# %%
country_grp = df.groupby(['Country'])
country_grp.get_group('India')
# Out:
#        ResponseId                                         MainBranch  \
# 28791       28792                     I am a developer by profession
# 12700       12701                     I am a developer by profession
# 64387       64388                     I am a developer by profession
# 12793       12794                     I am a developer by profession
# 3640         3641                     I am a developer by profession
# ...           ...                                                ...
# 83386       83387                     I am a developer by profession
# 83397       83398  I used to be a developer by profession, but no...
# 83406       83407             I am a student who is learning to code
# 83410       83411             I am a student who is learning to code
# 83417       83418                     I am a developer by profession
#
#                 Employment Country US_State UK_Country  \
# 28791   Employed full-time   India      NaN        NaN
# ...

# %%
country_grp['NEWOtherComms'].value_counts().loc['India']
# Out:
# NEWOtherComms
# False    6865
# True     3532
# Name: NEWOtherComms, dtype: int64

# %%
country_grp['SalaryUSD'].median().loc['India']
# Out:
# 14748.0

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     75631.000000
# mean      135732.563006
# Name: Canada, dtype: float64

# %%
country_uses_python= country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Papua New Guinea                                            1
# Dominica                                                    1
# Saint Kitts and Nevis                                       1
# Saint Vincent and the Grenadines                            1
# Name: Country, Length: 181, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Liechtenstein                                             1
# Papua New Guinea                                          1
# Dominica                                                  1
# Saint Kitts and Nevis                                     1
# Saint Vincent and the Grenadines                          1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageHaveWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     15288
# India                                                        10511
# Germany                                                       5625
# United Kingdom of Great Britain and Northern Ir...            4475
# Canada                                                        3012
# ...                                                            ...
# Liechtenstein                                                    1
# Papua New Guinea                                                 1
# Dominica                                                         1
# Saint Kitts and Nevis                                            1
# Saint Vincent and the Grenadines                                 1
#
#                                                     NumKnowsPython
# United States of America                                      7975
# ...

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     15288
# India                                                        10511
# Germany                                                       5625
# United Kingdom of Great Britain and Northern Ir...            4475
# Canada                                                        3012
# ...                                                            ...
# Liechtenstein                                                    1
# Papua New Guinea                                                 1
# Dominica                                                         1
# Saint Kitts and Nevis                                            1
# Saint Vincent and the Grenadines                                 1
#
#                                                     NumKnowsPython  \
# United States of America                                      7975
# ...

# %%
df['YearsCode'].head(10)
# Out:
# 65399     7
# 22666     5
# 27198     3
# 31086    16
# 44640     7
# 11377     8
# 17486     7
# 51428     7
# 14882     8
# 17120     3
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array(['7', '5', '3', '16', '8', 'Less than 1 year', '6', '4', nan, '2',
#        '10', '9', '11', 'More than 50 years', '32', '1', '20', '23', '12',
#        '13', '25', '30', '15', '18', '46', '14', '17', '37', '28', '40',
#        '35', '26', '38', '19', '22', '21', '33', '31', '36', '24', '34',
#        '27', '41', '43', '50', '29', '45', '42', '48', '39', '47', '49',
#        '44'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)
df['YearsCode'].unique()
# Out:
# array(['7', '5', '3', '16', '8', 0, '6', '4', nan, '2', '10', '9', '11',
#        51, '32', '1', '20', '23', '12', '13', '25', '30', '15', '18',
#        '46', '14', '17', '37', '28', '40', '35', '26', '38', '19', '22',
#        '21', '33', '31', '36', '24', '34', '27', '41', '43', '50', '29',
#        '45', '42', '48', '39', '47', '49', '44'], dtype=object)
